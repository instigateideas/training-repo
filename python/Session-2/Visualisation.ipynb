# %% [markdown]
# ## Visualization
#
# - Visualizing data is essential to exploring and presenting data.
# - The saying “a picture is worth a thousand words” certainly applies to understanding data.
# - Explaining your data is also often easier when you have visuals.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
X = list(np.arange(9))
Y = [20, 21, 35, 45, 70, 80, 54, 71, 73]

# %%
plt.plot(X, Y)
plt.title("Students Marks in English")
plt.xlabel("Student Roll No.")
plt.ylabel("Marks")
plt.show()

# %% [markdown]
# ## Styling Plots

# %%
## Styling Plots - markers
plt.plot(X, Y, marker='s')
plt.title("Students Marks in English")
plt.xlabel("Student Roll No.")
plt.ylabel("Marks")
plt.show()

# %%
## Styling Plots - linestyle (dotted: ":", dashed: "--", solid-line: "-", dash-dot line: "-.")
plt.plot(X, Y, marker='s', linestyle="-.")
plt.title("Students Marks in English")
plt.xlabel("Student Roll No.")
plt.ylabel("Marks")
plt.show()

# %%
## Styling Plots - lcolor - red, blue, green, cyan, magenta, black
plt.plot(X, Y, marker='s', linestyle="--", color="red")
plt.title("Students Marks in English")
plt.xlabel("Student Roll No.")
plt.ylabel("Marks")
plt.show()

# %%
## Styling Plots - linewidth
plt.plot(X, Y, marker='s', linestyle=":", color="blue", linewidth=2.5)
plt.title("Students Marks in English")
plt.xlabel("Student Roll No.")
plt.ylabel("Marks")
plt.show()

# %% [markdown]
# ## Plotting Labeled data

# %%
data = {"Years": ["2000", "2002", "2004", "2006", "2008","2010","2012", "2014", "2016"],
        "Men": [189.1, 191.8, 193.5, 196.0, 194.7, 196.3, 194.4, 197.0, 197.8],
        "Women": [175.7, 176.4, 176.5, 176.2, 175.9, 175.9, 175.7, 175.8, 175.3]}

# %%
data
# Out:
# {'Years': ['2000',
#   '2002',
#   '2004',
#   '2006',
#   '2008',
#   '2010',
#   '2012',
#   '2014',
#   '2016'],
#  'Men': [189.1, 191.8, 193.5, 196.0, 194.7, 196.3, 194.4, 197.0, 197.8],
#  'Women': [175.7, 176.4, 176.5, 176.2, 175.9, 175.9, 175.7, 175.8, 175.3]}

# %%
height_df = pd.DataFrame(data)
height_df
# Out:
#   Years    Men  Women
# 0  2000  189.1  175.7
# 1  2002  191.8  176.4
# 2  2004  193.5  176.5
# 3  2006  196.0  176.2
# 4  2008  194.7  175.9
# 5  2010  196.3  175.9
# 6  2012  194.4  175.7
# 7  2014  197.0  175.8
# 8  2016  197.8  175.3

# %%
plt.plot('Years', 'Men', data=height_df)
plt.xlabel("Year")
plt.ylabel("Height")
# Out:
# Text(0, 0.5, 'Height')

# %% [markdown]
# ## Plotting Multiple sets in single graph

# %%
X = [0, 1, 2, 3, 4, 5, 7, 8, 9, 10]
Y = [20, 25, 35, 50, 10, 12, 20, 40, 70, 110]
fmt = 's-.r'
X1 = [0, 1, 2, 3, 4, 5, 7, 8, 9, 10]
Y2 = [90, 89, 87, 82, 72, 60, 45, 28, 10, 0]
fmt2 = '^k:'

# %%
plt.plot(X, Y, fmt)
plt.plot(X1, Y2, fmt2)

# %%
plt.plot('Years', 'Women', 'Men', data=height_df)
plt.xlabel('Year')
plt.ylabel('Height (Inches)')
plt.title("Heights over time")
plt.legend(['Women', 'Men'])

# %% [markdown]
# ## Plot Bar chart

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
## Scatter Plot
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
# Subplots
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
# Grid 
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %%
# Pie Chart
y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
# Plot the heights
x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()
